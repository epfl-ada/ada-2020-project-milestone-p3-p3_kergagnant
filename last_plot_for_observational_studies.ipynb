# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.figure_factory as ff

# %%
df_goodCheckins = pd.read_csv('good_checkins.csv')
df_badCheckins = pd.read_csv('bad_checkins.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ebba757bbff6> in <module>
# ----> 1 df_goodCheckins = pd.read_csv('good_checkins.csv')
#       2 df_badCheckins = pd.read_csv('bad_checkins.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
treated_food = df_goodCheckins[df_goodCheckins['Food']].groupby('business_id').count()
control_food = df_badCheckins[df_badCheckins['Food']].groupby('business_id').count()
treated_food = treated_food['review_id']
control_food = control_food['review_id']

# %%
# Entertainment, Merchant
treated_care = df_goodCheckins[df_goodCheckins['Food']].groupby('business_id').count()
control_care = df_badCheckins[df_badCheckins['Food']].groupby('business_id').count()
treated_care = treated_care['review_id']
control_care = control_care['review_id']

# %%
ax = sns.distplot(treated_food[treated_food <= 50], hist=True, label='treated');
ax = sns.distplot(control_food[control_food <= 50], hist=True, label='control')
ax.set(title='Business Visit distribution For Food Category',xlabel='Number of visits', ylabel='Visit density')
plt.legend()
plt.show()

# %%
fig = ff.create_distplot([treated_care[treated_care <= 50], control_care[control_care <= 50]], ['Treated', 'Control'], bin_size=.2, colors=colors,  show_hist=False)

fig.update_layout(title_text='Customized Distplot')
fig.show()

# %%
ff.create_distplot?
# Out:
# Object `ff.create_distplot` not found.
